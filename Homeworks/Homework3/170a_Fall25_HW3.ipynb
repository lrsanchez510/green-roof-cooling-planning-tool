# %% [markdown]
# # Fall 2025 CE170A HW3: Sensor Data Analysis
# v6 - Fall 2025: Prof. Kenichi Soga, Connor Geudeker
#
# Previous iterations developed by: Jaewon Saw, Shih-Hung Chiu, Renjie Wu, Yaobin Yang, and James Wang.

# %%
import os
# !wget "https://github.com/UCB-CE170a/Fall2025/raw/main/Homeworks/Homework3/ProcessedData.zip" -O ProcessedData.zip
# !unzip ProcessedData
# Out:
# --2025-10-17 20:11:21--  https://github.com/UCB-CE170a/Fall2025/raw/main/Homeworks/Homework3/ProcessedData.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/UCB-CE170a/Fall2025/main/Homeworks/Homework3/ProcessedData.zip [following]
# --2025-10-17 20:11:21--  https://raw.githubusercontent.com/UCB-CE170a/Fall2025/main/Homeworks/Homework3/ProcessedData.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40944772 (39M) [application/zip]
# Saving to: ‘ProcessedData.zip’
#
# ProcessedData.zip   100%[===================>]  39.05M   187MB/s    in 0.2s
#
# 2025-10-17 20:11:22 (187 MB/s) - ‘ProcessedData.zip’ saved [40944772/40944772]
#
# Archive:  ProcessedData.zip
#    creating: ProcessedData/
#    creating: ProcessedData/Test1/
#    creating: ProcessedData/Test1/FiberOpticData/
#   inflating: ProcessedData/Test1/FiberOpticData/LM_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/MN_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/NP_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/KP_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/KM_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/MN_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/NP_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/JP_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/JK_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/KP_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/JP_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/JK_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/KL_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/LM_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/KM_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/KL_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/FL_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/FM_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/GM_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/HN_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/HP_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/BP_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/BC_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/CH_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/BH_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/BC_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/CD_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/DF_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/CF_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/CD_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/DF_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/FG_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/GH_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/CH_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/CF_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/FG_U.csv
#   inflating: ProcessedData/Test1/FiberOpticData/GH_A.csv
#   inflating: ProcessedData/Test1/FiberOpticData/BH_A.csv
#    creating: ProcessedData/Test1/LoadData/
#   inflating: ProcessedData/Test1/LoadData/ActuatorLoad [kN].csv
#   inflating: ProcessedData/Test1/LoadData/ActuatorDisplacement [m].csv
#    creating: ProcessedData/Test1/WirePotData/
#   inflating: ProcessedData/Test1/WirePotData/WirePot1 [m].csv
#   inflating: ProcessedData/Test1/WirePotData/WirePot2 [m].csv
#   inflating: ProcessedData/Test1/WirePotData/WirePot3 [m].csv
#   inflating: ProcessedData/Test1/WirePotData/WirePot4 [m].csv
#    creating: ProcessedData/Test1/LVDTData/
#   inflating: ProcessedData/Test1/LVDTData/LVDT1 [m].csv
#   inflating: ProcessedData/Test1/LVDTData/LVDT2 [m].csv
#   inflating: ProcessedData/Test1/LVDTData/LVDT3 [m].csv
#   inflating: ProcessedData/Test1/LVDTData/LVDT4 [m].csv
#    creating: ProcessedData/Test1/TiltData/
#   inflating: ProcessedData/Test1/TiltData/SouthLongitudinal.csv
#   inflating: ProcessedData/Test1/TiltData/NorthLongitudinal.csv
#   inflating: ProcessedData/Test1/TiltData/SouthTransverse.csv
#   inflating: ProcessedData/Test1/TiltData/NorthTransverse.csv
#    creating: ProcessedData/Test2/
#    creating: ProcessedData/Test2/FiberOpticData/
#   inflating: ProcessedData/Test2/FiberOpticData/LM_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/MN_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/NP_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/KP_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/KM_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/MN_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/NP_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/JP_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/JK_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/KP_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/JP_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/JK_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/KL_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/LM_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/KM_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/KL_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/FL_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/FM_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/GM_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/HN_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/HP_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/BP_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/BC_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/CH_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/BH_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/BC_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/CD_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/DF_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/CF_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/CD_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/DF_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/FG_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/GH_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/CH_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/CF_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/FG_U.csv
#   inflating: ProcessedData/Test2/FiberOpticData/GH_A.csv
#   inflating: ProcessedData/Test2/FiberOpticData/BH_A.csv
#    creating: ProcessedData/Test2/LoadData/
#   inflating: ProcessedData/Test2/LoadData/ActuatorLoad [kN].csv
#   inflating: ProcessedData/Test2/LoadData/ActuatorDisplacement [m].csv
#    creating: ProcessedData/Test2/LVDTData/
#   inflating: ProcessedData/Test2/LVDTData/LVDT1 [m].csv
#   inflating: ProcessedData/Test2/LVDTData/LVDT2 [m].csv
#   inflating: ProcessedData/Test2/LVDTData/LVDT3 [m].csv
#   inflating: ProcessedData/Test2/LVDTData/LVDT4 [m].csv
#    creating: ProcessedData/Test2/WirePotData/
#   inflating: ProcessedData/Test2/WirePotData/WirePot1 [m].csv
#   inflating: ProcessedData/Test2/WirePotData/WirePot2 [m].csv
#   inflating: ProcessedData/Test2/WirePotData/WirePot3 [m].csv
#   inflating: ProcessedData/Test2/WirePotData/WirePot4 [m].csv
#    creating: ProcessedData/Test2/TiltData/
#   inflating: ProcessedData/Test2/TiltData/NorthTransverse.csv
#   inflating: ProcessedData/Test2/TiltData/SouthLongitudinal.csv
#   inflating: ProcessedData/Test2/TiltData/NorthLongitudinal.csv
#   inflating: ProcessedData/Test2/TiltData/SouthTransverse.csv
#    creating: ProcessedData/Test3/
#    creating: ProcessedData/Test3/FiberOpticData/
#   inflating: ProcessedData/Test3/FiberOpticData/LM_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/MN_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/NP_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/KP_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/KM_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/MN_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/NP_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/JP_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/JK_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/KP_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/JP_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/JK_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/KL_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/LM_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/KM_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/KL_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/FL_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/FM_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/GM_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/HN_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/HP_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/BP_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/BC_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/CH_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/BH_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/BC_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/CD_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/DF_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/CF_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/CD_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/DF_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/FG_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/GH_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/CH_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/CF_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/FG_U.csv
#   inflating: ProcessedData/Test3/FiberOpticData/GH_A.csv
#   inflating: ProcessedData/Test3/FiberOpticData/BH_A.csv
#    creating: ProcessedData/Test3/LoadData/
#   inflating: ProcessedData/Test3/LoadData/ActuatorLoad [kN].csv
#   inflating: ProcessedData/Test3/LoadData/ActuatorDisplacement [m].csv
#    creating: ProcessedData/Test3/LVDTData/
#   inflating: ProcessedData/Test3/LVDTData/LVDT1 [m].csv
#   inflating: ProcessedData/Test3/LVDTData/LVDT2 [m].csv
#   inflating: ProcessedData/Test3/LVDTData/LVDT3 [m].csv
#   inflating: ProcessedData/Test3/LVDTData/LVDT4 [m].csv
#    creating: ProcessedData/Test3/WirePotData/
#   inflating: ProcessedData/Test3/WirePotData/WirePot1 [m].csv
#   inflating: ProcessedData/Test3/WirePotData/WirePot2 [m].csv
#   inflating: ProcessedData/Test3/WirePotData/WirePot3 [m].csv
#   inflating: ProcessedData/Test3/WirePotData/WirePot4 [m].csv
#    creating: ProcessedData/Test3/TiltData/
#   inflating: ProcessedData/Test3/TiltData/SouthTransverse.csv
#   inflating: ProcessedData/Test3/TiltData/SouthLongitudinal.csv
#   inflating: ProcessedData/Test3/TiltData/NorthTransverse.csv
#   inflating: ProcessedData/Test3/TiltData/NorthLongitudinal.csv

# %% [markdown]
# ## Background
#
# There are two ways to understand phenomena scientifically. One is through mathematical modeling and computer simulation, which is the purpose of our quiz 3 (truss finite element simulation). The other is through experiments, which are performed in this class (model bridge loading experiment). By comparing experimental results with simulation results, one may appreciate the complexity of real-world phenomena and have a deeper understanding of the power and limitations of the simulation method.

# %% [markdown]
# <center>
# <img src="https://github.com/UCB-CE170a/Fall2020/raw/master/homeworks/hw5/figures/overview.png" alt="Node numbering" width="600" />
#
#     Figure 1. Simulation Vs. Experiment
# </center>

# %% [markdown]
# In this assignment, you are going to analyze the sensor data from the model bridge experiment and compare the result with the truss simulation performed in Quiz 3. The data you are going to explore are as follows:
# * Displacement data from displacement sensors (potentiometric measuring devices),
# * Tilt data from WSN tilt motes, and
# * Distributed (spatial) strain data from fiber optics sensors.

# %% [markdown]
# The typical workflow of data analysis is summarized in Figure 2.
# <center>
# <img src="https://github.com/UCB-CE170a/Fall2020/raw/master/homeworks/hw5/figures/data_processing.png" alt="Node numbering" width="600" />
#
#     Figure 2. Typical workflow of data analysis
# </center>

# %% [markdown]
# We start with the raw data collected from the sensor systems. Then, we preprocess the raw data and store the cleaned data into a data storage system. There are various reasons for data preprocessing. Missing data handling, experiment/equipment setting adjustment, and data format conversion are common reasons (there are more, of course).
#
# Most data can be represented as a single spreadsheet. Such data include the displacement data and tilt data that we are going to explore in this assignment. However, in some cases, data can have complex structures; such as the distributed strain data we have in this case. The distributed strain data is collected from fiber optics sensors, which record the strain along with the fiber (spatial component) during the experiment (time component). As you all know, we deployed numerous fiber optics sensors (with different lengths) across different structure members to monitor the load responses of the model bridge. Since we have three model bridges this year, each with different sensor deployment strategies, the sensors' raw data are huge and hard to handle. For the ease of this exercise, the distributed strain data is preprocessed by us, and only some cleaned data from certain bridge members are presented here.
#
#
# Having the cleaned data on our hands, we can perform various postprocessing techniques such as statistical analysis, and most importantly, visualize the data for interpretation.
#
# The data are given in a format that follows the numbering given in the following figures.
#
# Figure 3 shows the nodal numbering of the model bridge.
# <center>
# <img src="https://github.com/UCB-CE170a/Fall2025/raw/main/Homeworks/Homework3/Figures/BridgeNamingConvention.png" alt="Node numbering" width="500" />
#
#     Figure 3. Node numbering for the model bridge
# </center>

# %% [markdown]
# ## Videos from bridge tests
# Refer to the videos on the <a href="https://bcourses.berkeley.edu/courses/1547912/external_tools/90481">BCourses</a>
#  to look back on any details you need for the following sections.

# %% [markdown]
# # Data Exploration

# %% [markdown]
# We tested three bridges: (1) Standard Bridge, (2) Student Damaged and (3) Staff Damaged. Throughout this assignment, we will use the indices 1, 2, and 3 to refer to those bridges.
#
# Let's first install the required libraries and then read the processed data for the three bridges (in desired units and format) that we'll need for our analysis.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from IPython.display import *
import ipywidgets as widgets
from ipywidgets import *

# %% [markdown]
# The following cell block simply sets up an interactive function that will allow us to quickly look at and sift through the data. You can select multiple tests, a sensor of interest, and multiple datapoints of interest. Additionally you can manipulate the value on the x-axis and if you'd like to plot all the data or until "failure" (peak load). From there you can plot and assign this data to the variable. While the function call below is to let you see how the function works, please do not edit the other function calls as they are directed to help you complete the assignment.

# %%
test_widget = widgets.SelectMultiple(options=['Test1', 'Test2', 'Test3'])
sensor_widget = widgets.Dropdown()
data_widget = widgets.SelectMultiple()
xValue = widgets.Dropdown(options = ["Time [s]","Load [kN]"],value = "Time [s]")

def getFileNames(filePath):
  filenames=[]
  for filename in os.listdir(filePath):
    f = os.path.join(filePath, filename)
    filenames.append(f)
  return filenames

def update_sensors(*args):
  #sourceFolder = '/content'
  sourceFolder = os.getcwd()
  try:
    newFolders = getFileNames(sourceFolder+'/ProcessedData/'+test_widget.value+'/')
  except:
    newFolders = getFileNames(sourceFolder+'/ProcessedData/Test1/')
  options = np.sort(np.array([folder.split('/')[-1] for folder in newFolders])).tolist()
  sensor_widget.options = options
test_widget.observe(update_sensors)

def update_data(*args):
  #sourceFolder = '/content'
  sourceFolder = os.getcwd()
  try:
    newFolders = getFileNames(sourceFolder+'/ProcessedData/'+test_widget.value[0]+'/'+sensor_widget.value+'/')
  except:
    newFolders = getFileNames(sourceFolder+'/ProcessedData/Test1/FiberOpticData/')
  options = np.sort(np.array([folder.split('/')[-1] for folder in newFolders])).tolist()
  data_widget.options = options
sensor_widget.observe(update_data)

plot = Checkbox(False, description='Ready to plot data?')
peak = Checkbox(False, description="Cutoff at peak?")

def uncheckBox(*args):
  plot.value = False
test_widget.observe(uncheckBox)
sensor_widget.observe(uncheckBox)
data_widget.observe(uncheckBox)

def plottingData(test,sensor,data,xAxisData,plotData,peakEnd):
  global dataDFs
  #filePath = '/content'
  filePath= os.getcwd()
  tests = list(test_widget.value)
  datas = list(data_widget.value)
  if (not tests) | (not datas):
    plotData = False
    print("Not enough information selected yet.")
  else:
    print("Enough information has been selected.")
  if plotData:
    legendItems = []
    dataDFs = []
    fig = plt.figure()
    ax = fig.gca()
    for test in tests:
      xAxisFilePath = filePath + '/ProcessedData/' + test +'/LoadData/ActuatorLoad [kN].csv'
      xDF = pd.read_csv(xAxisFilePath,delimiter=',',index_col=False)
      startTime = np.array([0,0,0])[np.array(test_widget.options)==test][0]
      if peak.value:
        endTime = np.array([50,50,50])[np.array(test_widget.options)==test][0]
      else:
        endTime = xDF.iloc[-1,1]
      xDF = xDF[xDF.iloc[:,1]<=endTime]
      xDF = xDF[xDF.iloc[:,1]>=startTime]
      xDF.iloc[:,1] = xDF.iloc[:,1] - startTime
      if xValue.value == "Time [s]":
        xData = xDF.iloc[:,1]
      else:
        xData = xDF.iloc[:,-1]
      for data in datas:
        testFilePath = filePath + '/ProcessedData/'+test +'/'+sensor_widget.value+'/'+data
        dataDF = pd.read_csv(testFilePath,delimiter=',',index_col=False).astype(np.float32)
        dataDF = dataDF.drop(columns = [dataDF.columns.to_list()[0]])
        dataDF = dataDF[dataDF.iloc[:,0]<=endTime]
        # Ensure xData and dataDF.iloc[:,0] are the same length
        min_len = min(len(xData), len(dataDF.iloc[:,0]))
        xData = xData[:min_len]
        dataDF = dataDF.iloc[:min_len, :]
        dataDF.iloc[:,0] = xData
        dataDF.rename(columns={ dataDF.columns[0]: xValue.value }, inplace = True)
        dataDFs.append(dataDF)
        plt.plot(dataDF.iloc[:,0],dataDF.iloc[:,-1])
        legendItems.append(test+data)
    plt.xlabel(xValue.value)
    plt.ylabel(dataDF.columns.to_list()[-1])
    ax.grid(color = [0.8, 0.8, 0.8], which = 'major')
    ax.xaxis.set_ticks_position('both')
    ax.yaxis.set_ticks_position('both')
    ax.tick_params(direction="in", which = 'major', length = 6, width = 1)
    ax.tick_params(direction="in", which = 'minor', length = 3, width = 0.6)

    ax.set_title(sensor_widget.value+' vs. '+xValue.value, fontsize = 14)
    plt.legend(legendItems)
    plt.show()
  else:
    print("Change the options and then check the box to load the graph.")

testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)
# Out:
# interactive(children=(SelectMultiple(description='test', options=('Test1', 'Test2', 'Test3'), value=()), Dropd…

# %% [markdown]
# # (1) Loading processes
# Let's take a look at the loading processes first.

# %%
# Load appropriate information
test_widget.value = ('Test1', 'Test2', 'Test3')
sensor_widget.value = 'LoadData'
data_widget.value = ('ActuatorLoad [kN].csv',)
xValue.value = "Time [s]"
plot.value = True
peak.value = False

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)
# Out:
# interactive(children=(SelectMultiple(description='test', index=(0, 1, 2), options=('Test1', 'Test2', 'Test3'),…

# %%
# Load appropriate information
test_widget.value = ('Test1', 'Test2', 'Test3')
sensor_widget.value = 'LoadData'
data_widget.value = ('ActuatorDisplacement [m].csv',)
xValue.value = "Time [s]"
plot.value = True
peak.value = False

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)
# Out:
# interactive(children=(SelectMultiple(description='test', index=(0, 1, 2), options=('Test1', 'Test2', 'Test3'),…

# %% [markdown]
# <font color='red'>Question: </font> For each bridge, what were the maximum load and the corresponding time taken to reach the maximum load? Does the above plot match your on-site observations? Is the plot as you would expect? (Hint: think about softening behavior)

# %% [markdown]
# <font color='red'>Answer: </font> For bridge 1 the maximum load reached was roughly 35 kN and the time taken to reach this maximum load was 50 seconds. For bridge 2 the maximum load reached was roughly 39.5 kN and the time taken to reach this maximum load was around 40 seconds. For bridge 3 the maximum load reached was roughly 62 kN and the time taken to reach this maximum load was around 122 seconds.

# %% [markdown]
# # (2) Expansion of bottom members

# %% [markdown]
# Now let's take a look at how the bottom members responded to the load. To see the expansion of those members, we will need data from the linear variable differential transformers (LVDTs) that we placed at each end of the bottom members. As seen from Figures 3 and 4, we see that we need LVDTs 2 and 4 for member BD.
# <center>
# <img src="https://github.com/UCB-CE170a/Fall2025/raw/main/Homeworks/Homework3/Figures/LVDTWPConfiguration.png" alt="Node numbering" width="800" />
#
#     Figure 4.1 LVDT and WirePot configuration for the experiment.
# </center>
#
# <center>
# <img src="https://github.com/UCB-CE170a/Fall2021/raw/master/Homeworks/HW2/images/figure4.png" alt="A bridge." width="600" />
#
#     Figure 4.2 Dimensions of the model
# </center>

# %% [markdown]
# ## (2.1) Member BD

# %% [markdown]
# Lets first load and plot the data collected for the LVDT's on either side of Member BD: LVDT2 and LVDT4. We'll focus on the values up until the peak load, since the large deformations after this point resulted in difficult to interpret data likely related to the movement of the LVDT itself.

# %%
# Load appropriate information
test_widget.value = ('Test1', 'Test2', 'Test3')
sensor_widget.value = 'LVDTData'
data_widget.value = ('LVDT2 [m].csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)
# Out:
# interactive(children=(SelectMultiple(description='test', index=(0, 1, 2), options=('Test1', 'Test2', 'Test3'),…

# %%
# Call information
LVDTWDFs = dataDFs

# %%
# Load appropriate information
test_widget.value = ('Test1', 'Test2', 'Test3')
sensor_widget.value = 'LVDTData'
data_widget.value = ('LVDT4 [m].csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)
# Out:
# interactive(children=(SelectMultiple(description='test', index=(0, 1, 2), options=('Test1', 'Test2', 'Test3'),…

# %%
# Call information
LVDTEDFs = dataDFs

# %% [markdown]
# Now, we use the LVDT 2 and LVDT 4 data to plot the expansion of member BD:

# %%
fig = plt.figure()
ax = fig.gca()
for i in [0,1,2]:
  expansion = LVDTWDFs[i].iloc[:,-1].to_numpy()+LVDTEDFs[i].iloc[:,-1].to_numpy()
  plt.plot(LVDTWDFs[i].iloc[:,0],expansion)
plt.xlabel("Load [kN]")
plt.ylabel("Expansion [m]")
ax.grid(color = [0.8, 0.8, 0.8], which = 'major')
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.tick_params(direction="in", which = 'major', length = 6, width = 1)
ax.tick_params(direction="in", which = 'minor', length = 3, width = 0.6)
ax.set_title('Expansion BD vs. Load', fontsize = 14)
plt.legend(["Test1","Test2","Test3"])
plt.ylim([0,0.005])
plt.show()

# %% [markdown]
# <font color='red'>Question: </font> For each of the three bridges, describe the behavior of the LVDTs and the behavior of the bottom member using the plotted figures above. Given these displacements, what strains would you expect in the bottom members? How do the experimental results compare to your Quiz 3 calculations?

# %% [markdown]
# <font color='red'>Answer:</font>

# %% [markdown]
# ## (2.2) Transverse Displacements
# Let's see if there is anything interesting in the Transverse displacement of the bridge:

# %%
# Load appropriate information
test_widget.value = ('Test1', 'Test2', 'Test3')
sensor_widget.value = 'LVDTData'
data_widget.value = ('LVDT1 [m].csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1840808809.py in <cell line: 0>()
#       1 # Load appropriate information
# ----> 2 test_widget.value = ('Test1', 'Test2', 'Test3')
#       3 sensor_widget.value = 'LVDTData'
#       4 data_widget.value = ('LVDT1 [m].csv',)
#       5 xValue.value = "Load [kN]"
#
# NameError: name 'test_widget' is not defined

# %%
# Load appropriate information
test_widget.value = ('Test1', 'Test2', 'Test3')
sensor_widget.value = 'LVDTData'
data_widget.value = ('LVDT3 [m].csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %% [markdown]
# <font color='red'>Question: </font> What do you think about these results? What information can we discern from them? (We don't have a notable comparison or expectation, so feel free to be creative.)

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# # (3) Rotation at the top of the bridge

# %% [markdown]
# Let's explore the tiltmeter data. Figure 5 shows the orientation of the WSN tilt meters. Both were located on the top of the bridge, one towards the North end and one towards the South end. The direction of angle is given for both longitudinal direction (L) and transverse direction (T).

# %% [markdown]
# <center>
# <img src="https://github.com/UCB-CE170a/Fall2021/raw/master/Homeworks/HW2/images/tilt_defination.jpg" alt="Node numbering" width="600" />
#
#     Figure 5. The locations of WSN tilt motes.
# </center>

# %%
# Load appropriate information
test_widget.value = ('Test1',)
sensor_widget.value = 'TiltData'
data_widget.value = ('NorthLongitudinal.csv','SouthLongitudinal.csv','SouthTransverse.csv','NorthTransverse.csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %%
# Load appropriate information
test_widget.value = ('Test2',)
sensor_widget.value = 'TiltData'
data_widget.value = ('NorthLongitudinal.csv','SouthLongitudinal.csv','SouthTransverse.csv','NorthTransverse.csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %%
# Load appropriate information
test_widget.value = ('Test3',)
sensor_widget.value = 'TiltData'
data_widget.value = ('NorthLongitudinal.csv','SouthLongitudinal.csv','SouthTransverse.csv','NorthTransverse.csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %% [markdown]
# <font color='red'>Question: </font> Using the three rotation plots above, compare and discuss how the bridges behaved as they were about to fail. Do the failure patterns match the your observations?

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# <font color='red'>Question: </font> How could these be helpful for structural health monitoring?

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# We can also calculate a tilt value of the top plate by looking at the results of the wire potentiometers. The following plots the original data and processes it to derive this "global" tilt.

# %%
def tiltFromWirePot(WirePotData):
  T1WPData = WirePotData
  dT = 0.178
  dL = 0.145
  angleTs = []
  angleLs = []
  for i in range(0,len(T1WPData[0])):
    wp1 = np.array([0,0,T1WPData[1].iloc[i,1]]) # Bottom Left: WP2
    wp2 = np.array([0,dT,T1WPData[2].iloc[i,1]]) # Top Left: WP3
    wp3 = np.array([dL,dT,T1WPData[0].iloc[i,1]]) # Top Right: WP1
    wp4 = np.array([dL,0,T1WPData[3].iloc[i,1]]) # Bottom Right: WP4
    a1,b1,c1 = np.cross(wp3-wp1,wp2-wp1)
    a2,b2,c2 = np.cross(wp4-wp1,wp3-wp1)
    a3,b3,c3 = np.cross(wp4-wp2,wp3-wp2)
    a4,b4,c4 = np.cross(wp4-wp1,wp2-wp1)
    normal = np.array([np.mean([a1,a2,a3,a4]),np.mean([b1,b2,b3,b4]),np.mean([c1,c2,c3,c4])])
    normalT = normal*np.array([0,1,1])
    normalL = normal*np.array([1,0,1])
    angleT= (180/np.pi)*np.arccos(np.dot(normalT,np.array([0,0,1]))/np.linalg.norm(normalT))
    angleL= (180/np.pi)*np.arccos(np.dot(normalL,np.array([0,0,1]))/np.linalg.norm(normalL))
    angleTs.append(-angleT)
    angleLs.append(angleL)

  angleTs = angleTs - angleTs[0]
  angleLs = angleLs - angleLs[0]
  fig = plt.figure()
  ax = fig.gca()
  plt.plot(T1WPData[0].iloc[:,0],angleTs)
  plt.plot(T1WPData[0].iloc[:,0],angleLs)
  plt.xlabel(T1WPData[0].columns.to_list()[0])
  plt.ylabel("Angle (degrees)")
  ax.grid(color = [0.8, 0.8, 0.8], which = 'major')
  ax.xaxis.set_ticks_position('both')
  ax.yaxis.set_ticks_position('both')
  ax.tick_params(direction="in", which = 'major', length = 6, width = 1)
  ax.tick_params(direction="in", which = 'minor', length = 3, width = 0.6)
  ax.set_title('WirePot Angle vs. Load', fontsize = 14)
  plt.legend(["Transverse","Longitudinal"])
  plt.show()

# %%
# Load appropriate information
test_widget.value = ('Test1',)
sensor_widget.value = 'WirePotData'
data_widget.value = ('WirePot1 [m].csv', 'WirePot2 [m].csv', 'WirePot3 [m].csv', 'WirePot4 [m].csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %%
tiltFromWirePot(dataDFs)

# %%
# Load appropriate information
test_widget.value = ('Test2',)
sensor_widget.value = 'WirePotData'
data_widget.value = ('WirePot1 [m].csv', 'WirePot2 [m].csv', 'WirePot3 [m].csv', 'WirePot4 [m].csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %%
tiltFromWirePot(dataDFs)

# %%
# Load appropriate information
test_widget.value = ('Test3',)
sensor_widget.value = 'WirePotData'
data_widget.value = ('WirePot1 [m].csv', 'WirePot2 [m].csv', 'WirePot3 [m].csv', 'WirePot4 [m].csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %%
tiltFromWirePot(dataDFs)

# %% [markdown]
# <font color='red'>Question: </font> How do the plots above compare to the data collected by the tilt meters? Is this as useful as the tilt meter system?

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# # (4) Behavior of individual members

# %% [markdown]
# Finally, let's explore the most interesting data, the distributed strain data collected from the fiber optics sensors. The model bridge memberes are divided into 4 planes: Bottom, Diagonal, Middle and Transverse planes. As we didn't investigate these in the simulation, transverse elements will not be investigated. See Figure 3 above, where the corresponding element colors are blue, red, yellow and green.
#
# As discussed earlier, the raw data collected by the fiber optics sensors are spatially distributed. Specifically, the data contains spatial strain information at each sample time for each fiber. The general preprocessing process is listed as the following:
# * Cleaning: Convert data format, remove headers, convert units, remove meaningless items...
# * Time synchronization: all the collected data is time-stamped. Unfortunately, the timing systems for different measurement equipment might be slightly different. For instance, the clock in the fiber optics analyzer is 2 minutes and 19 seconds faster than the one measuring the loading process. Synchronizing times across all equipment make the comparison/plotting of different measurements possible.
# * Resampling: Sometimes, the sampling rates across different equipment are different. To compare different measurements from different machines (i.e., load vs. strain), one needs to resample the collected data to match the time stamp.
# * Normalization: Some fibers are pre tensioned, meaning the starting measurement may not be 0. Doing normalization for the data makes the measurement (strain) comparable across different bridges.
# * Downsampling: Additionally, we've collected a LOT of data through this process. So much so, that we need to downsample in order to share through GitHub. Accordingly, fiber optic data is available in 5.2 mm resolution instead of the typical 2.6 mm.
#
# <font color='red'>Note: the data you see in this section is far from perfect. If some data does not make any sense to you, think about the potential causes for that. Try your best to discuss your findings.  </font>
#
# We'll focus on the results of the first test for this section, with the exception of the bottom members, where we will look at the third test.

# %% [markdown]
# We first reread the load data, which has now been synchronized with the fiber optic data in time:

# %% [markdown]
# The first row of the data provides the spatial location for each strain measurement points alone the fiber. The rest of the rows are the strain measurements across the fiber (5.2 mm resolution) for every sample time. To access the strain measurement for certain truss members, one need to know the corresponding spatial locations of the member on the fiber. Luckily, our kind GSI did indexing (truss member end points to fiber locations) for all the truss members for all three bridges, so we know how to access the member from the data.
#
# The indexing convention is as follows:
#
# * `{node1}{node2}_{inside or outside}.csv`
#  * `BC_A.csv` refers to the strain "above" Member BC
#  * `EF_U.csv` refers to the strain "under" Member FG
#
# The "above" and "under" sections of an element are depicted in Figure 8.

# %% [markdown]
# ## Time (load) Data Analysis
# Since different groups wired fiber cables in different ways and analyzing both spatial and temporal data requires skills beyond the boundary of this class, simplified strain data is used in the later part of the assignment. Certain truss members are extracted from the data for all bridges, and only the average (spatial averaged) strain for each truss member is provided along with the corresponding load levels.
#
# For those who are inclined towards structural engineering, or are just generally curious, it may be interesting to investigate the baseline values. You'll see within a member where strain concentrations occur.
#
# <font color='green'>**NOTE: Please subtract "initial strains" or more clearly the strains that build up at 0 load. In this case it is often 200.**<font>

# %% [markdown]
# ## (4.1) Diagonal Members

# %%
# Load appropriate information
test_widget.value = ('Test3',)
sensor_widget.value = 'FiberOpticData'
data_widget.value = ('GH_U.csv', 'GH_A.csv', 'FG_A.csv', 'FG_U.csv')
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %% [markdown]
# <font color='red'>Question: </font> Describe any similarities and differences between the members. What is the strain at approximately 10 kN? Does it match your predictions? Explain your reasoning.

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# ## (4.2) Bottom Members

# %%
# Load appropriate information
# Using Test 2 because of Section 5
test_widget.value = ('Test3',)
sensor_widget.value = 'FiberOpticData'
data_widget.value = ('BC_A.csv', 'CD_A.csv', 'JK_A.csv', 'KL_A.csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %% [markdown]
# <font color='red'>Question: </font> Describe any similarities and differences between the members. What is the strain at approximately 10 kN? Does it match your predictions? Explain your reasoning.

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# ## (4.3) Middle Section Diagonal Members

# %%
# Load appropriate information
test_widget.value = ('Test3',)
sensor_widget.value = 'FiberOpticData'
data_widget.value = ('CH_A.csv', 'CF_A.csv', 'KM_A.csv', 'KP_A.csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %% [markdown]
# <font color='red'>Question: </font> Describe any similarities and differences between the members. Is this plot as you would expect? Explain your reasoning.

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# # (5) Importance of Implementation

# %% [markdown]
# In this section, we want to answer the question: *What is the importance of how instrumentation is attached to the structure?*
#
# Below we have a comparison of three of the bottom members of Test 1. Fiber optic cables were implemented in the following fashion:
# * Member BC: Taped to surface.
# * Member CD: Epoxied in three 3" segments.
# * Member KL: Continuous epoxy. (Traditional approach)

# %%
# Load appropriate information
test_widget.value = ('Test1',)
sensor_widget.value = 'FiberOpticData'
data_widget.value = ('BC_U.csv', 'CD_U.csv', 'KL_U.csv',)
xValue.value = "Load [kN]"
plot.value = True
peak.value = True

# Call new manual interact
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %% [markdown]
# <font color='red'><b>Question (1): </b></font> What are you seeing in the above plot? Which implementations work best? Worst?

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# <font color='red'><b>Question (2): </b></font> What are the potential implications of poor implementation? What are some other ways the implementation of monitoring equipment could ultimately render it useless?
# * Hint: Think how outside factors can influence readings or how we ensure whe have implemented equipment properly.

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# # Discussion

# %% [markdown]
# <font color='red'><b>Question (1): </b></font> Use the strain-load plots for the diagonal members (GH, FG) from problem (4.1) to revise the stiffness of the material in your FE model. Are your estimations the same across the four different members? How do they compare to the theoretical value?
#
# * Hint 1: "Load" from data is the system (total) load. Go back to Quiz 3 to find the equation to convert total load to the load felt by each member. Again, pay attention to number of angle bars for each member.
#
# * Hint 2: Reading the values from the graph is acceptable.

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# <font color='red'><b>Question (2):</b> </font> Think back to what you observed during the tests. (Watch the videos in the <a href="https://bcourses.berkeley.edu/courses/1547912/external_tools/90481">media gallery</a> if it helps.) Describe the deformation mechanisms of the bridges as a whole at different loading stages.

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# <font color='red'><b>Question (3):</b></font> Discuss the validity of the assumptions that we made in the analysis given in Quiz 3.

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# <font color='red'><b>Question (4):</b></font> If you could improve the simulation analysis, what would you do?

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# <font color='red'><b>Question (5):</b></font> If you were allowed to add more sensors to the model bridge, what and where would you add?

# %% [markdown]
# <font color='red'>Answer: </font>

# %% [markdown]
# # Further Investigation
#
# We collected a lot of data which wasn't presented or analyzed above. If you're intereseted, we encourage you to investigate futher and see what you can find out/develop. Some suggestive questions are provided below towards this end.
#
#
# *   What can we interpret by looking at the inside and outside fiberoptic of the diagonal members?
# *   Strains were collected, but what else can we determine from this?
# *   What can we learn by looking at spatial strain data fiber optics provide?
# *   Some members had rather odd average strain profiles? Why was this?

# %% [markdown]
# Modify the inputs for this to whatever you'd like to pull. You can open multiple instances, but only the most recent data will be kept in the variable `dataDFs`, which is a list of the Pandas DataFrames containing the data specified in the function.

# %%
testInteract = interact_manual(plottingData,
                               test=test_widget,
                               sensor=sensor_widget,
                               data=data_widget,
                               xAxisData = xValue,
                               plotData = plot,
                               peakEnd=peak)

# %% [markdown]
# If you want to keep the data, you'll need to assign it to another variable.

# %%
dataList = dataDFs
